# %% [markdown]
# ### Importing packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Importing dataset

# %%
bikeFrame = pd.read_csv('s3://rmit-ml-2020s1-lab-data/Bike-Sharing-Dataset/bikeShareDay.csv', delimiter='\s+')

# %%
print(bikeFrame)
# Out:
#     instant,dteday,season,yr,mnth,holiday,weekday,workingday,weathersit,temp,atemp,hum,windspeed,casual,registered,cnt
# 0    1,2011-01-01,1,0,1,0,6,0,2,0.344167,0.363625,0...
# 1    2,2011-01-02,1,0,1,0,0,0,2,0.363478,0.353739,0...
# 2    3,2011-01-03,1,0,1,0,1,1,1,0.196364,0.189405,0...
# 3    4,2011-01-04,1,0,1,0,2,1,1,0.2,0.212122,0.5904...
# 4    5,2011-01-05,1,0,1,0,3,1,1,0.226957,0.22927,0....
# 5    6,2011-01-06,1,0,1,0,4,1,1,0.204348,0.233209,0...
# 6    7,2011-01-07,1,0,1,0,5,1,2,0.196522,0.208839,0...
# 7    8,2011-01-08,1,0,1,0,6,0,2,0.165,0.162254,0.53...
# 8    9,2011-01-09,1,0,1,0,0,0,1,0.138333,0.116175,0...
# 9    10,2011-01-10,1,0,1,0,1,1,1,0.150833,0.150888,...
# 10   11,2011-01-11,1,0,1,0,2,1,2,0.169091,0.191464,...
# 11   12,2011-01-12,1,0,1,0,3,1,1,0.172727,0.160473,...
# 12   13,2011-01-13,1,0,1,0,4,1,1,0.165,0.150883,0.4...
# 13   14,2011-01-14,1,0,1,0,5,1,1,0.16087,0.188413,0...
# 14   15,2011-01-15,1,0,1,0,6,0,2,0.233333,0.248112,...
# ...
